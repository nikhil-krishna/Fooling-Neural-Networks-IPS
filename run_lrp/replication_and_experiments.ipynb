# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# CHANGE DIRECTORY TO run_lrp
cd drive/My\ Drive/Mini4/run_lrp

# %%
# MUST HAVE THESE VERSIONS FOR CODE TO WORK
# !pip install visdom
# !pip install torch==0.4.1
# !pip install torchvision==0.2.1

# %%
# Replication, Experiment 1, and Experiment 2
# Uncomment/comment necessary parts of passive_fooling.sh before running
# !bash passive_fooling.sh

# %%
# Experiment 3
# !bash passive_fooling_demo.sh
